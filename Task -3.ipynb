# %% [markdown]
# # Importing Data

# %%
import os
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from seaborn_qqplot import pplot
from matplotlib import pyplot as plt
from statsmodels.graphics.gofplots import qqplot
import warnings
warnings.filterwarnings('ignore')

# %%
os.chdir("A:\DATA\Imartics\Python")
df = pd.read_csv("adult.csv")
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              50  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %% [markdown]
# # Treat the Missing Values

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
df['occupation'].replace('?',np.NaN,inplace=True)
df['occupation'].value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
df.shape
# Out:
# (48842, 15)

# %%
df['workclass'].replace('?',np.NaN,inplace=True)
df['workclass'].value_counts()
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
df['native-country'].replace('?',np.NaN,inplace=True)
df['native-country'].value_counts()
# Out:
# United-States                 43832
# Mexico                          951
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# Greece                           49
# Peru                             46
# Ecuador                          45
# France                           38
# Ireland                          37
# Thailand                         30
# Hong                             30
# Cambodia                         28
# Trinadad&Tobago                  27
# Yugoslavia                       23
# Laos                             23
# Outlying-US(Guam-USVI-etc)       23
# Scotland                         21
# Honduras                         20
# Hungary                          19
# Holand-Netherlands                1
# Name: native-country, dtype: int64

# %%
df['workclass'].mode()
# Out:
# 0    Private
# dtype: object

# %%
df['native-country'].mode()
# Out:
# 0    United-States
# dtype: object

# %%
df['occupation'].mode()
# Out:
# 0    Prof-specialty
# dtype: object

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.dtypes
# Out:
# age                 int64
# workclass          object
# fnlwgt              int64
# education          object
# educational-num     int64
# marital-status     object
# occupation         object
# relationship       object
# race               object
# gender             object
# capital-gain        int64
# capital-loss        int64
# hours-per-week      int64
# native-country     object
# income             object
# dtype: object

# %%
x=df.mean()
x
# Out:
# age                    38.643585
# fnlwgt             189664.134597
# educational-num        10.078089
# capital-gain         1079.067626
# capital-loss           87.502314
# hours-per-week         40.422382
# dtype: float64

# %%
df.median()
# Out:
# age                    37.0
# fnlwgt             178144.5
# educational-num        10.0
# capital-gain            0.0
# capital-loss            0.0
# hours-per-week         40.0
# dtype: float64

# %%
df.mode()
# Out:
#    age workclass  fnlwgt education  educational-num      marital-status  \
# 0   36   Private  203488   HS-grad                9  Married-civ-spouse
#
#        occupation relationship   race gender  capital-gain  capital-loss  \
# 0  Prof-specialty      Husband  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K

# %% [markdown]
# # Treat the Outliers

# %%
plt.figure(figsize=(19,12))


num_feat = df.select_dtypes(include=['int64']).columns

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.boxplot(df[num_feat[i]])
    plt.title(num_feat[i],color="b",fontsize=20)
    plt.yticks(fontsize=14)
    plt.xticks(fontsize=14)

# %%
lower_bound =0.1
upper_bound=0.95
res = df.quantile([lower_bound,upper_bound])
res
# Out:
#        age     fnlwgt  educational-num  capital-gain  capital-loss  \
# 0.10  22.0   65738.20              7.0           0.0           0.0
# 0.95  63.0  379481.65             14.0        5013.0           0.0
#
#       hours-per-week
# 0.10            24.0
# 0.95            60.0

# %% [markdown]
# # Winsorizing
#
# 1.Analyze your data to make sure the outlier isn’t a result of measurement error or some other fixable error.
#
# 2.Decide how much Winsorization you want. This is specified as a total percentage of untouched data. For example, if you want to Winsorize the top 5% and bottom 5% of data points, this is equal to 100% – 5% – 5% = 90% Winsorization. A 80% Winsorization means that 10% is modified from each tail area (see Tips on Cut-Off Point Selection below).
#
# 3.Replace the extreme values by the maximum and/or minimum values at the threshold

# %%
from scipy.stats.mstats import winsorize
df["age"]           = winsorize(df["age"],(0,0.10))
df["fnlwgt"]        = winsorize(df["fnlwgt"],(0,0.10))
df["educational-num"]  = winsorize(df["educational-num"],(0,0.099))
df["capital-gain"]  = winsorize(df["capital-gain"],(0,0.099))
df["capital-loss"]  = winsorize(df["capital-loss"],(0,0.099))
df["hours-per-week"]= winsorize(df["hours-per-week"],(0.10,0.20))

# %%
plt.figure(figsize=(19,12))


num_feat = df.select_dtypes(include=['int64']).columns

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.boxplot(df[num_feat[i]])
    plt.title(num_feat[i],color="b",fontsize=20)
    plt.yticks(fontsize=14)
    plt.xticks(fontsize=14)

# %% [markdown]
# # Z-score
#
# A Z-score is a numerical measurement that describes a value's relationship to the mean of a group of values. Z-score is measured in terms of standard deviations from the mean. If a Z-score is 0, it indicates that the data point's score is identical to the mean score
#
# ![image.png](attachment:image.png)
#
#
# Z	=	standard score
#
# x	=	observed value
#
# $\mu$	=	mean of the sample
#
# $ \sigma$	=	standard deviation of the sample

# %%
y=df.std()
y
# Out:
# age                   12.275084
# fnlwgt             84930.006592
# educational-num        2.373058
# capital-gain           0.000000
# capital-loss           0.000000
# hours-per-week         7.184808
# dtype: float64

# %%
dfz=(df-x)/y
dfz
# Out:
#             age  capital-gain  capital-loss education  educational-num  \
# 0     -1.111486          -inf          -inf       NaN        -1.297098
# 1     -0.052430          -inf          -inf       NaN        -0.454304
# 2     -0.867089          -inf          -inf       NaN         0.809888
# 3      0.436365          -inf          -inf       NaN        -0.032906
# 4     -1.681747          -inf          -inf       NaN        -0.032906
# ...         ...           ...           ...       ...              ...
# 48837 -0.948554          -inf          -inf       NaN         0.809888
# 48838  0.110501          -inf          -inf       NaN        -0.454304
# 48839  1.576886          -inf          -inf       NaN        -0.454304
# 48840 -1.355884          -inf          -inf       NaN        -0.454304
# 48841  1.088091          -inf          -inf       NaN        -0.454304
#
#          fnlwgt gender  hours-per-week income marital-status native-country  \
# 0      0.437276    NaN       -0.058788    NaN            NaN            NaN
# 1     -1.175676    NaN        1.054672    NaN            NaN            NaN
# 2      1.634309    NaN       -0.058788    NaN            NaN            NaN
# 3     -0.345474    NaN       -0.058788    NaN            NaN            NaN
# 4     -1.014566    NaN       -1.450614    NaN            NaN            NaN
# ...         ...    ...             ...    ...            ...            ...
# 48837  0.796395    NaN       -0.337153    NaN            NaN            NaN
# 48838 -0.415520    NaN       -0.058788    NaN            NaN            NaN
# 48839 -0.444532    NaN       -0.058788    NaN            NaN            NaN
# 48840  0.139242    NaN       -2.285709    NaN            NaN            NaN
# 48841  1.156986    NaN       -0.058788    NaN            NaN            NaN
#
#       occupation race relationship workclass
# 0            NaN  NaN          NaN       NaN
# 1            NaN  NaN          NaN       NaN
# 2            NaN  NaN          NaN       NaN
# 3            NaN  NaN          NaN       NaN
# 4            NaN  NaN          NaN       NaN
# ...          ...  ...          ...       ...
# 48837        NaN  NaN          NaN       NaN
# 48838        NaN  NaN          NaN       NaN
# 48839        NaN  NaN          NaN       NaN
# 48840        NaN  NaN          NaN       NaN
# 48841        NaN  NaN          NaN       NaN
#
# [48842 rows x 15 columns]

# %%
num_var=[]
cat_var=[]
for i in df.columns:
    if (df[i].dtypes=='object'):
        cat_var.append(i)
    else:
        num_var.append(i)

# %%
num_var
# Out:
# ['age',
#  'fnlwgt',
#  'educational-num',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week']

# %%
cat_var
# Out:
# ['workclass',
#  'education',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'gender',
#  'native-country',
#  'income']

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Histograms

# %%
for i in num_var:
    plt.figure(figsize=(10,8))
    sns.histplot(df[i],kde=False,bins=20)

# %% [markdown]
# Univariate Histgram
#
# Age plot have 50-60 age people are high
#
# fnlwgt plot have greater the 30000
#
# education-num plot is the 12 range of Assoc-acdm
#
# captical-loss and captical-gain is not get more
#
# hours-per-week work is the 40hrs/week

# %%
for i in num_var:
    plt.figure(figsize=(10,8))
    sns.boxplot(df[i])

# %% [markdown]
# box plot
#
# education-num and hour-per-week has the more outliers

# %%
for i in cat_var:
    plt.figure(figsize=(10,8))
    sns.countplot(df[i])

# %% [markdown]
# Count plot
#
# gender and income plot male is get highest income
#
# race is the white people is large number

# %%
for i in num_var:
    plt.figure(figsize=(10,8))
    sns.kdeplot(x=df[i])

# %% [markdown]
# # Bivariate Analysis

# %% [markdown]
# # Scatter plots

# %%
for i in num_var:
    plt.figure(figsize=(12,8))
    sns.scatterplot(x="age",y=df[i],data=df)
    plt.show()

# %% [markdown]
# # Hexbin plots

# %%
for i in num_var:
    plt.figure(figsize=(10,8))
    sns.jointplot(data=df, x="fnlwgt", y=df[i], kind="hex",color="#4CB391")
    plt.show()

# %% [markdown]
# # Pairolpt

# %%
sns.pairplot(df)

# %% [markdown]
# # Box Plot

# %%
for i in cat_var:
    plt.figure(figsize=(8,8))
    sns.boxplot(x=df[i], y='age',data=df)
    plt.show()

# %% [markdown]
# # Bar Plot

# %%
for i in cat_var:
    plt.figure(figsize=(10,10))
    sns.barplot(x=df[i], y='fnlwgt',data=df)
    plt.show()

# %% [markdown]
# # Strip Polt

# %%
for i in cat_var:
    plt.figure(figsize=(10,10))
    sns.stripplot(x=df[i], y='fnlwgt',data=df)
    plt.show()

# %% [markdown]
# # Numerical Features Column For Standardization

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split

# %%
X=df[['fnlwgt','educational-num','capital-gain','capital-loss','hours-per-week']]
Y=df['age']

print(X.head)
# Out:
# <bound method NDFrame.head of        fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week
# 0      226802                7             0             0              40
# 1       89814                9             0             0              48
# 2      328466               12             0             0              40
# 3      160323               10             0             0              40
# 4      103497               10             0             0              30
# ...       ...              ...           ...           ...             ...
# 48837  257302               12             0             0              38
# 48838  154374                9             0             0              40
# 48839  151910                9             0             0              40
# 48840  201490                9             0             0              24
# 48841  287927                9             0             0              40
#
# [48842 rows x 5 columns]>

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3)

# %%
X_train_stand = X_train.copy()
X_test_stand = X_test.copy()

# %%
num_cols=['fnlwgt','educational-num','capital-gain','capital-loss','hours-per-week']
for i in num_cols:
    scale = StandardScaler().fit(X_train_stand[[i]])
    X_train_stand[i] = scale.transform(X_train_stand[[i]])
    X_test_stand[i] = scale.transform(X_test_stand[[i]])

# %%
missing_val_count_by_column = (df.isnull().sum())
print(missing_val_count_by_column[missing_val_count_by_column > 0])
# Out:
# workclass         2799
# occupation        2809
# native-country     857
# dtype: int64

# %%
X_train_stand
# Out:
#          fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week
# 1346   0.500384         0.444085           0.0           0.0        0.087692
# 22122  0.168322         1.286733           0.0           0.0        1.201607
# 3335   0.082174        -0.398562           0.0           0.0        1.201607
# 45464 -1.681962        -0.398562           0.0           0.0        1.201607
# 14682  0.646115         0.022761           0.0           0.0        0.087692
# ...         ...              ...           ...           ...             ...
# 27956 -1.819167         0.444085           0.0           0.0        1.201607
# 1538  -1.554400         1.286733           0.0           0.0        1.201607
# 27939  1.605740         0.022761           0.0           0.0       -1.304701
# 6824   1.725872        -0.398562           0.0           0.0        0.087692
# 21729 -0.944253        -0.398562           0.0           0.0        1.201607
#
# [34189 rows x 5 columns]

# %%
X_test_stand
# Out:
#          fnlwgt  educational-num  capital-gain  capital-loss  hours-per-week
# 14490  0.465353         0.022761           0.0           0.0        0.087692
# 26109  0.403438         1.286733           0.0           0.0        1.201607
# 36358  0.023474        -1.662534           0.0           0.0        0.087692
# 39369 -0.187586         0.444085           0.0           0.0       -1.304701
# 17692  0.177177        -0.398562           0.0           0.0        1.201607
# ...         ...              ...           ...           ...             ...
# 41401 -1.564680         1.286733           0.0           0.0        1.201607
# 8332  -1.131409         0.444085           0.0           0.0       -0.190787
# 28336 -1.298441        -0.398562           0.0           0.0        0.087692
# 39127 -0.983347         0.865409           0.0           0.0        0.644649
# 22518  0.094608        -2.505181           0.0           0.0        1.201607
#
# [14653 rows x 5 columns]

# %% [markdown]
# # Using Dummy variables For Categorica

# %%
df["gender"] = df.gender.map({'Male':1,'Female':0})

# %%
df["race"] = df.race.map({'Black':1,'White':0})

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  328466    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18        NaN  103497  Some-college               10       Never-married
#
#           occupation relationship  race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child   1.0       1             0             0
# 1    Farming-fishing      Husband   0.0       1             0             0
# 2    Protective-serv      Husband   0.0       1             0             0
# 3  Machine-op-inspct      Husband   1.0       1             0             0
# 4                NaN    Own-child   0.0       0             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# 1              48  United-States  <=50K
# 2              40  United-States   >50K
# 3              40  United-States   >50K
# 4              30  United-States  <=50K

# %%
pd.get_dummies(df,columns=["race","gender",])
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  328466    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18           NaN  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship  capital-gain  \
# 0           Never-married  Machine-op-inspct    Own-child             0
# 1      Married-civ-spouse    Farming-fishing      Husband             0
# 2      Married-civ-spouse    Protective-serv      Husband             0
# 3      Married-civ-spouse  Machine-op-inspct      Husband             0
# 4           Never-married                NaN    Own-child             0
# ...                   ...                ...          ...           ...
# 48837  Married-civ-spouse       Tech-support         Wife             0
# 48838  Married-civ-spouse  Machine-op-inspct      Husband             0
# 48839             Widowed       Adm-clerical    Unmarried             0
# 48840       Never-married       Adm-clerical    Own-child             0
# 48841  Married-civ-spouse    Exec-managerial         Wife             0
#
#        capital-loss  hours-per-week native-country income  race_0.0  race_1.0  \
# 0                 0              40  United-States  <=50K         0         1
# 1                 0              48  United-States  <=50K         1         0
# 2                 0              40  United-States   >50K         1         0
# 3                 0              40  United-States   >50K         0         1
# 4                 0              30  United-States  <=50K         1         0
# ...             ...             ...            ...    ...       ...       ...
# 48837             0              38  United-States  <=50K         1         0
# 48838             0              40  United-States   >50K         1         0
# 48839             0              40  United-States  <=50K         1         0
# 48840             0              24  United-States  <=50K         1         0
# 48841             0              40  United-States   >50K         1         0
#
#        gender_0  gender_1
# 0             0         1
# 1             0         1
# 2             0         1
# 3             0         1
# 4             1         0
# ...         ...       ...
# 48837         1         0
# 48838         0         1
# 48839         1         0
# 48840         0         1
# 48841         1         0
#
# [48842 rows x 17 columns]

# %% [markdown]
# # Prove Central Limit Theorem on ‘age’

# %%
from scipy.stats import norm 
age=np.array(df.age)

# %%
plt.figure(figsize=(10, 8))
plt.title('Age', size=8)
plt.xlabel('Value in $', size=8)
sns.distplot(age, fit=norm, color='blue', kde=False)
# Out:
# <AxesSubplot:title={'center':'Age'}, xlabel='Value in $'>

# %% [markdown]
# # Mean

# %%
sample_num = 1000
sample_size = 300

mean_sample_values = []

for i in range(sample_num):
    sample_mean = np.mean(np.random.choice(age, sample_size, replace=True))
    mean_sample_values.append(sample_mean)

# %%
plt.figure(figsize=(12, 8))
plt.title('Sample Mean of Age', size=10)
plt.xlabel('Value in $', size=10)
sns.distplot(mean_sample_values, fit=norm, color='red', kde=False)
# Out:
# <AxesSubplot:title={'center':'Sample Mean of Age'}, xlabel='Value in $'>

# %% [markdown]
# # Median

# %%
sample_num = 1000
sample_size = 300

median_sample_values = []

for i in range(sample_num):
    sample_median = np.median(np.random.choice(age, sample_size, replace=True))
    median_sample_values.append(sample_median)

# %%
plt.figure(figsize=(12, 8))
plt.title('Sample Median of Age', size=10)
plt.xlabel('Value in $', size=10)
sns.distplot(median_sample_values, fit=norm, color='green', kde=False)
# Out:
# <AxesSubplot:title={'center':'Sample Median of Age'}, xlabel='Value in $'>

# %% [markdown]
# Plotting the sample means distribution, which approaches a normal distribution. As we can see, the central limit theorem is indeed true

# %% [markdown]
# # Chi Square Test For Relationship between Occupation and gender
#
# Chi-square Test for Feature Extraction:
# Chi-square test is used for categorical features in a dataset. We calculate Chi-square between each feature and the target and select the desired number of features with best Chi-square scores. It determines if the association between two categorical variables of the sample would reflect their real association in the population.
# Chi- square score is given by :
#
# ![image.png](attachment:image.png)

# %%
from scipy.stats import chi2
from scipy.stats import chi2_contingency

# %%
df.gender.value_counts()
# Out:
# 1    32650
# 0    16192
# Name: gender, dtype: int64

# %%
df.occupation.value_counts()
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
pd.crosstab(df.occupation, df.gender, margins=True)
# Out:
# gender                 0      1    All
# occupation
# Adm-clerical        3769   1842   5611
# Armed-Forces           0     15     15
# Craft-repair         323   5789   6112
# Exec-managerial     1748   4338   6086
# Farming-fishing       95   1395   1490
# Handlers-cleaners    254   1818   2072
# Machine-op-inspct    804   2218   3022
# Other-service       2698   2225   4923
# Priv-house-serv      228     14    242
# Prof-specialty      2242   3930   6172
# Protective-serv      122    861    983
# Sales               1947   3557   5504
# Tech-support         562    884   1446
# Transport-moving     127   2228   2355
# All                14919  31114  46033

# %%
observed = pd.crosstab(df.occupation,df.gender)
observed
# Out:
# gender                0     1
# occupation
# Adm-clerical       3769  1842
# Armed-Forces          0    15
# Craft-repair        323  5789
# Exec-managerial    1748  4338
# Farming-fishing      95  1395
# Handlers-cleaners   254  1818
# Machine-op-inspct   804  2218
# Other-service      2698  2225
# Priv-house-serv     228    14
# Prof-specialty     2242  3930
# Protective-serv     122   861
# Sales              1947  3557
# Tech-support        562   884
# Transport-moving    127  2228

# %%
chi2_contingency(observed)
# Out:
# (8690.69415082913,
#  0.0,
#  13,
#  array([[1818.48910564, 3792.51089436],
#         [   4.86140378,   10.13859622],
#         [1980.85999175, 4131.14000825],
#         [1972.43355853, 4113.56644147],
#         [ 482.8994417 , 1007.1005583 ],
#         [ 671.5219082 , 1400.4780918 ],
#         [ 979.41081398, 2042.58918602],
#         [1595.51271914, 3327.48728086],
#         [  78.43064758,  163.56935242],
#         [2000.30560685, 4171.69439315],
#         [ 318.58399409,  664.41600591],
#         [1783.81109204, 3720.18890796],
#         [ 468.63932396,  977.36067604],
#         [ 763.24039276, 1591.75960724]]))

# %%
chi2_test_stat = chi2_contingency(observed)[0]
pval = chi2_contingency(observed)[1]
df = chi2_contingency(observed)[2]

# %%
alpha = 1 - 0.90

chi2_critical = chi2.ppf(1 - alpha, df)

chi2_critical
# Out:
# 19.81192930712756

# %%
x_min = 0
x_max = 100

x = np.linspace(x_min, x_max, 100)
y = chi2.pdf(x, df)
plt.xlim(x_min, x_max)
plt.plot(x, y)

chi2_critical_right = chi2_critical

x1 = np.linspace(chi2_critical_right, x_max, 100)
y1 = chi2.pdf(x1, df)
plt.fill_between(x1, y1, color='red')

# %%
if(chi2_test_stat > chi2_critical):
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Reject Null Hypothesis

# %%
if(pval < alpha):
    print("Reject Null Hypothesis")
else:
    print("Fail to Reject Null Hypothesis")
# Out:
# Reject Null Hypothesis
